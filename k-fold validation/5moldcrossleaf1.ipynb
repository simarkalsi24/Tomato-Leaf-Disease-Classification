# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# === CONFIGURATION ===
IMAGE_SIZE = 256
BATCH_SIZE = 32
EPOCHS = 25
FOLDS = 5
DATASET_DIR = "augmented_dataset"  # 👈 Folder containing class-named subfolders

# === STEP 1: Load all image paths and labels from folder structure ===
data = []
for class_name in os.listdir(DATASET_DIR):
    class_path = os.path.join(DATASET_DIR, class_name)
    if os.path.isdir(class_path):
        for img in os.listdir(class_path):
            if img.lower().endswith(('.jpg', '.jpeg', '.png')):
                data.append([os.path.join(class_path, img), class_name])

df = pd.DataFrame(data, columns=["filename", "class"])
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# === STEP 2: Label Encoding ===
label_map = {label: idx for idx, label in enumerate(sorted(df["class"].unique()))}
df["class_idx"] = df["class"].map(label_map)
NUM_CLASSES = len(label_map)

# === STEP 3: CNN Model ===
def build_cnn_model(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), num_classes=NUM_CLASSES):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.Conv2D(32, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),

        layers.GlobalAveragePooling2D(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# === STEP 4: Data Generator ===
datagen = ImageDataGenerator(rescale=1./255)

# === STEP 5: K-Fold Cross-Validation ===
skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=42)
fold_accuracies = []
fold_histories = []

for fold, (train_idx, val_idx) in enumerate(skf.split(df["filename"], df["class_idx"])):
    print(f"\n🟦 Fold {fold+1}/{FOLDS}")

    train_df = df.iloc[train_idx]
    val_df = df.iloc[val_idx]

    train_gen = datagen.flow_from_dataframe(
        train_df,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        class_mode="categorical",
        batch_size=BATCH_SIZE,
        shuffle=True,
        seed=42
    )

    val_gen = datagen.flow_from_dataframe(
        val_df,
        x_col="filename",
        y_col="class",
        target_size=(IMAGE_SIZE, IMAGE_SIZE),
        class_mode="categorical",
        batch_size=BATCH_SIZE,
        shuffle=False
    )

    model = build_cnn_model()
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        callbacks=[early_stop, lr_reduce],
        verbose=1
    )

    val_loss, val_acc = model.evaluate(val_gen, verbose=0)
    fold_histories.append(history.history)
    fold_accuracies.append(val_acc)
    print(f"✅ Fold {fold+1} Accuracy: {val_acc:.4f}")

# === STEP 6: Summary ===
mean_acc = np.mean(fold_accuracies)
std_acc = np.std(fold_accuracies)
print(f"\n📊 5-Fold Validation Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")

# === STEP 7: Accuracy/Loss Plot ===
def plot_kfold_results(histories):
    fig, axs = plt.subplots(2, 1, figsize=(12, 10))

    for i, history in enumerate(histories):
        axs[0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[0].plot(history['val_accuracy'], linestyle='--', label=f'Val Fold {i+1}')
        axs[1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[1].plot(history['val_loss'], linestyle='--', label=f'Val Fold {i+1}')

    axs[0].set_title('Training vs Validation Accuracy (All Folds)')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()
    axs[0].grid()

    axs[1].set_title('Training vs Validation Loss (All Folds)')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid()

    plt.tight_layout()
    plt.show()

plot_kfold_results(fold_histories)
# Out:
# 🟦 Fold 1/5
# Found 23757 validated image filenames belonging to 10 classes.
# Found 5940 validated image filenames belonging to 10 classes.
# 2025-07-02 07:39:59.589686: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-07-02 07:39:59.589731: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-07-02 07:39:59.589735: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2025-07-02 07:39:59.589774: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-02 07:39:59.589785: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/simarkalsi/Projects/leaf K-cross/kcross/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 2025-07-02 07:40:00.296686: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 99ms/step - accuracy: 0.3933 - loss: 1.8110 - val_accuracy: 0.6818 - val_loss: 0.9433 - learning_rate: 1.0000e-04
# Epoch 2/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.6579 - loss: 0.9916 - val_accuracy: 0.7133 - val_loss: 0.8546 - learning_rate: 1.0000e-04
# Epoch 3/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.7350 - loss: 0.7823 - val_accuracy: 0.8199 - val_loss: 0.5542 - learning_rate: 1.0000e-04
# Epoch 4/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.7806 - loss: 0.6563 - val_accuracy: 0.8412 - val_loss: 0.4775 - learning_rate: 1.0000e-04
# Epoch 5/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 76s 103ms/step - accuracy: 0.8108 - loss: 0.5687 - val_accuracy: 0.8621 - val_loss: 0.4080 - learning_rate: 1.0000e-04
# Epoch 6/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.8289 - loss: 0.5042 - val_accuracy: 0.8785 - val_loss: 0.3719 - learning_rate: 1.0000e-04
# Epoch 7/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.8463 - loss: 0.4778 - val_accuracy: 0.8806 - val_loss: 0.3611 - learning_rate: 1.0000e-04
# Epoch 8/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.8543 - loss: 0.4380 - val_accuracy: 0.8253 - val_loss: 0.5518 - learning_rate: 1.0000e-04
# Epoch 9/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.8594 - loss: 0.4200 - val_accuracy: 0.8973 - val_loss: 0.2949 - learning_rate: 1.0000e-04
# Epoch 10/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.8778 - loss: 0.3694 - val_accuracy: 0.8840 - val_loss: 0.3436 - learning_rate: 1.0000e-04
# Epoch 11/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.8807 - loss: 0.3562 - val_accuracy: 0.9013 - val_loss: 0.2836 - learning_rate: 1.0000e-04
# Epoch 12/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.8905 - loss: 0.3341 - val_accuracy: 0.9108 - val_loss: 0.2659 - learning_rate: 1.0000e-04
# Epoch 13/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.8929 - loss: 0.3204 - val_accuracy: 0.8700 - val_loss: 0.3810 - learning_rate: 1.0000e-04
# Epoch 14/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.8934 - loss: 0.3172 - val_accuracy: 0.9268 - val_loss: 0.2178 - learning_rate: 1.0000e-04
# Epoch 15/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9019 - loss: 0.2921 - val_accuracy: 0.9310 - val_loss: 0.2162 - learning_rate: 1.0000e-04
# Epoch 16/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.9066 - loss: 0.2854 - val_accuracy: 0.9320 - val_loss: 0.2070 - learning_rate: 1.0000e-04
# Epoch 17/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9108 - loss: 0.2725 - val_accuracy: 0.9246 - val_loss: 0.2176 - learning_rate: 1.0000e-04
# Epoch 18/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9158 - loss: 0.2536 - val_accuracy: 0.9256 - val_loss: 0.2257 - learning_rate: 1.0000e-04
# Epoch 19/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9173 - loss: 0.2430 - val_accuracy: 0.9372 - val_loss: 0.1923 - learning_rate: 1.0000e-04
# Epoch 20/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9191 - loss: 0.2378 - val_accuracy: 0.9283 - val_loss: 0.2114 - learning_rate: 1.0000e-04
# Epoch 21/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9283 - loss: 0.2220 - val_accuracy: 0.9394 - val_loss: 0.1831 - learning_rate: 1.0000e-04
# Epoch 22/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9274 - loss: 0.2191 - val_accuracy: 0.9460 - val_loss: 0.1528 - learning_rate: 1.0000e-04
# Epoch 23/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9286 - loss: 0.2131 - val_accuracy: 0.9438 - val_loss: 0.1609 - learning_rate: 1.0000e-04
# Epoch 24/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9318 - loss: 0.2044 - val_accuracy: 0.9451 - val_loss: 0.1615 - learning_rate: 1.0000e-04
# Epoch 25/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 92s 123ms/step - accuracy: 0.9316 - loss: 0.2011 - val_accuracy: 0.9332 - val_loss: 0.1962 - learning_rate: 1.0000e-04
# ✅ Fold 1 Accuracy: 0.9460
#
# 🟦 Fold 2/5
# Found 23757 validated image filenames belonging to 10 classes.
# Found 5940 validated image filenames belonging to 10 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/leaf K-cross/kcross/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 83s 110ms/step - accuracy: 0.3974 - loss: 1.7816 - val_accuracy: 0.6699 - val_loss: 0.9336 - learning_rate: 1.0000e-04
# Epoch 2/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 81s 109ms/step - accuracy: 0.6656 - loss: 0.9656 - val_accuracy: 0.8059 - val_loss: 0.6147 - learning_rate: 1.0000e-04
# Epoch 3/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.7306 - loss: 0.7950 - val_accuracy: 0.8453 - val_loss: 0.4869 - learning_rate: 1.0000e-04
# Epoch 4/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 76s 102ms/step - accuracy: 0.7691 - loss: 0.6791 - val_accuracy: 0.8374 - val_loss: 0.4945 - learning_rate: 1.0000e-04
# Epoch 5/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.7966 - loss: 0.5923 - val_accuracy: 0.8513 - val_loss: 0.4468 - learning_rate: 1.0000e-04
# Epoch 6/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.8190 - loss: 0.5354 - val_accuracy: 0.8820 - val_loss: 0.3648 - learning_rate: 1.0000e-04
# Epoch 7/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.8421 - loss: 0.4722 - val_accuracy: 0.8830 - val_loss: 0.3642 - learning_rate: 1.0000e-04
# Epoch 8/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.8500 - loss: 0.4455 - val_accuracy: 0.8594 - val_loss: 0.4156 - learning_rate: 1.0000e-04
# Epoch 9/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.8636 - loss: 0.4070 - val_accuracy: 0.8684 - val_loss: 0.4094 - learning_rate: 1.0000e-04
# Epoch 10/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.8682 - loss: 0.3939 - val_accuracy: 0.9197 - val_loss: 0.2388 - learning_rate: 1.0000e-04
# Epoch 11/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.8847 - loss: 0.3517 - val_accuracy: 0.8746 - val_loss: 0.3430 - learning_rate: 1.0000e-04
# Epoch 12/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.8871 - loss: 0.3397 - val_accuracy: 0.8933 - val_loss: 0.3146 - learning_rate: 1.0000e-04
# Epoch 13/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.8923 - loss: 0.3232 - val_accuracy: 0.8860 - val_loss: 0.3166 - learning_rate: 1.0000e-04
# Epoch 14/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.9082 - loss: 0.2830 - val_accuracy: 0.9500 - val_loss: 0.1652 - learning_rate: 5.0000e-05
# Epoch 15/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9094 - loss: 0.2719 - val_accuracy: 0.9475 - val_loss: 0.1596 - learning_rate: 5.0000e-05
# Epoch 16/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9102 - loss: 0.2612 - val_accuracy: 0.9554 - val_loss: 0.1463 - learning_rate: 5.0000e-05
# Epoch 17/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9120 - loss: 0.2633 - val_accuracy: 0.9530 - val_loss: 0.1535 - learning_rate: 5.0000e-05
# Epoch 18/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9178 - loss: 0.2482 - val_accuracy: 0.9465 - val_loss: 0.1646 - learning_rate: 5.0000e-05
# Epoch 19/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9179 - loss: 0.2446 - val_accuracy: 0.9507 - val_loss: 0.1565 - learning_rate: 5.0000e-05
# Epoch 20/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9204 - loss: 0.2353 - val_accuracy: 0.9609 - val_loss: 0.1283 - learning_rate: 2.5000e-05
# Epoch 21/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9282 - loss: 0.2234 - val_accuracy: 0.9569 - val_loss: 0.1383 - learning_rate: 2.5000e-05
# Epoch 22/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9281 - loss: 0.2228 - val_accuracy: 0.9613 - val_loss: 0.1247 - learning_rate: 2.5000e-05
# Epoch 23/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9248 - loss: 0.2266 - val_accuracy: 0.9554 - val_loss: 0.1416 - learning_rate: 2.5000e-05
# Epoch 24/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9269 - loss: 0.2179 - val_accuracy: 0.9522 - val_loss: 0.1538 - learning_rate: 2.5000e-05
# Epoch 25/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9293 - loss: 0.2077 - val_accuracy: 0.9636 - val_loss: 0.1204 - learning_rate: 2.5000e-05
# ✅ Fold 2 Accuracy: 0.9636
#
# 🟦 Fold 3/5
# Found 23758 validated image filenames belonging to 10 classes.
# Found 5939 validated image filenames belonging to 10 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/leaf K-cross/kcross/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 76s 99ms/step - accuracy: 0.4283 - loss: 1.6450 - val_accuracy: 0.6627 - val_loss: 0.9650 - learning_rate: 1.0000e-04
# Epoch 2/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.6670 - loss: 0.9617 - val_accuracy: 0.7830 - val_loss: 0.6745 - learning_rate: 1.0000e-04
# Epoch 3/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.7391 - loss: 0.7626 - val_accuracy: 0.8370 - val_loss: 0.5151 - learning_rate: 1.0000e-04
# Epoch 4/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.7775 - loss: 0.6478 - val_accuracy: 0.8431 - val_loss: 0.4647 - learning_rate: 1.0000e-04
# Epoch 5/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.8075 - loss: 0.5608 - val_accuracy: 0.8766 - val_loss: 0.3720 - learning_rate: 1.0000e-04
# Epoch 6/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 76s 103ms/step - accuracy: 0.8288 - loss: 0.5101 - val_accuracy: 0.8823 - val_loss: 0.3504 - learning_rate: 1.0000e-04
# Epoch 7/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.8465 - loss: 0.4536 - val_accuracy: 0.8729 - val_loss: 0.3763 - learning_rate: 1.0000e-04
# Epoch 8/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.8617 - loss: 0.4086 - val_accuracy: 0.8687 - val_loss: 0.3669 - learning_rate: 1.0000e-04
# Epoch 9/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.8682 - loss: 0.3902 - val_accuracy: 0.9195 - val_loss: 0.2488 - learning_rate: 1.0000e-04
# Epoch 10/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.8814 - loss: 0.3551 - val_accuracy: 0.8900 - val_loss: 0.3212 - learning_rate: 1.0000e-04
# Epoch 11/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.8867 - loss: 0.3323 - val_accuracy: 0.9175 - val_loss: 0.2526 - learning_rate: 1.0000e-04
# Epoch 12/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.8933 - loss: 0.3131 - val_accuracy: 0.9227 - val_loss: 0.2337 - learning_rate: 1.0000e-04
# Epoch 13/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.9021 - loss: 0.2816 - val_accuracy: 0.9251 - val_loss: 0.2268 - learning_rate: 1.0000e-04
# Epoch 14/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.9107 - loss: 0.2626 - val_accuracy: 0.9289 - val_loss: 0.2091 - learning_rate: 1.0000e-04
# Epoch 15/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9133 - loss: 0.2634 - val_accuracy: 0.9365 - val_loss: 0.1877 - learning_rate: 1.0000e-04
# Epoch 16/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 99ms/step - accuracy: 0.9151 - loss: 0.2470 - val_accuracy: 0.9151 - val_loss: 0.2532 - learning_rate: 1.0000e-04
# Epoch 17/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.9188 - loss: 0.2437 - val_accuracy: 0.8767 - val_loss: 0.4013 - learning_rate: 1.0000e-04
# Epoch 18/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9265 - loss: 0.2268 - val_accuracy: 0.9355 - val_loss: 0.1983 - learning_rate: 1.0000e-04
# Epoch 19/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9326 - loss: 0.2036 - val_accuracy: 0.9554 - val_loss: 0.1405 - learning_rate: 5.0000e-05
# Epoch 20/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.9353 - loss: 0.1921 - val_accuracy: 0.9574 - val_loss: 0.1325 - learning_rate: 5.0000e-05
# Epoch 21/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 73s 98ms/step - accuracy: 0.9347 - loss: 0.1885 - val_accuracy: 0.9606 - val_loss: 0.1287 - learning_rate: 5.0000e-05
# Epoch 22/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9388 - loss: 0.1863 - val_accuracy: 0.9621 - val_loss: 0.1202 - learning_rate: 5.0000e-05
# Epoch 23/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9402 - loss: 0.1813 - val_accuracy: 0.9500 - val_loss: 0.1537 - learning_rate: 5.0000e-05
# Epoch 24/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.9442 - loss: 0.1678 - val_accuracy: 0.9480 - val_loss: 0.1456 - learning_rate: 5.0000e-05
# Epoch 25/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.9445 - loss: 0.1659 - val_accuracy: 0.9286 - val_loss: 0.2084 - learning_rate: 5.0000e-05
# ✅ Fold 3 Accuracy: 0.9621
#
# 🟦 Fold 4/5
# Found 23758 validated image filenames belonging to 10 classes.
# Found 5939 validated image filenames belonging to 10 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/leaf K-cross/kcross/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 76s 100ms/step - accuracy: 0.3822 - loss: 1.8272 - val_accuracy: 0.6819 - val_loss: 0.9399 - learning_rate: 1.0000e-04
# Epoch 2/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.6517 - loss: 1.0044 - val_accuracy: 0.7542 - val_loss: 0.6985 - learning_rate: 1.0000e-04
# Epoch 3/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.7261 - loss: 0.8040 - val_accuracy: 0.7488 - val_loss: 0.7103 - learning_rate: 1.0000e-04
# Epoch 4/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.7637 - loss: 0.7087 - val_accuracy: 0.8309 - val_loss: 0.5125 - learning_rate: 1.0000e-04
# Epoch 5/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.7983 - loss: 0.6065 - val_accuracy: 0.8786 - val_loss: 0.3780 - learning_rate: 1.0000e-04
# Epoch 6/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.8091 - loss: 0.5616 - val_accuracy: 0.8762 - val_loss: 0.3895 - learning_rate: 1.0000e-04
# Epoch 7/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.8279 - loss: 0.5140 - val_accuracy: 0.8631 - val_loss: 0.4206 - learning_rate: 1.0000e-04
# Epoch 8/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.8383 - loss: 0.4872 - val_accuracy: 0.8884 - val_loss: 0.3446 - learning_rate: 1.0000e-04
# Epoch 9/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.8534 - loss: 0.4373 - val_accuracy: 0.8961 - val_loss: 0.3157 - learning_rate: 1.0000e-04
# Epoch 10/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.8639 - loss: 0.4037 - val_accuracy: 0.8961 - val_loss: 0.3221 - learning_rate: 1.0000e-04
# Epoch 11/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.8711 - loss: 0.3824 - val_accuracy: 0.8848 - val_loss: 0.3245 - learning_rate: 1.0000e-04
# Epoch 12/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.8849 - loss: 0.3470 - val_accuracy: 0.9209 - val_loss: 0.2436 - learning_rate: 1.0000e-04
# Epoch 13/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.8891 - loss: 0.3347 - val_accuracy: 0.9261 - val_loss: 0.2166 - learning_rate: 1.0000e-04
# Epoch 14/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.8934 - loss: 0.3161 - val_accuracy: 0.9289 - val_loss: 0.2193 - learning_rate: 1.0000e-04
# Epoch 15/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9003 - loss: 0.2947 - val_accuracy: 0.9202 - val_loss: 0.2208 - learning_rate: 1.0000e-04
# Epoch 16/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 99ms/step - accuracy: 0.9067 - loss: 0.2782 - val_accuracy: 0.9444 - val_loss: 0.1690 - learning_rate: 1.0000e-04
# Epoch 17/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 100ms/step - accuracy: 0.9099 - loss: 0.2678 - val_accuracy: 0.8799 - val_loss: 0.3756 - learning_rate: 1.0000e-04
# Epoch 18/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 100ms/step - accuracy: 0.9121 - loss: 0.2585 - val_accuracy: 0.9156 - val_loss: 0.2617 - learning_rate: 1.0000e-04
# Epoch 19/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 100ms/step - accuracy: 0.9167 - loss: 0.2499 - val_accuracy: 0.9353 - val_loss: 0.1892 - learning_rate: 1.0000e-04
# Epoch 20/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 100ms/step - accuracy: 0.9252 - loss: 0.2213 - val_accuracy: 0.9544 - val_loss: 0.1374 - learning_rate: 5.0000e-05
# Epoch 21/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 100ms/step - accuracy: 0.9330 - loss: 0.2026 - val_accuracy: 0.9488 - val_loss: 0.1525 - learning_rate: 5.0000e-05
# Epoch 22/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 101ms/step - accuracy: 0.9352 - loss: 0.1958 - val_accuracy: 0.9561 - val_loss: 0.1299 - learning_rate: 5.0000e-05
# Epoch 23/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 101ms/step - accuracy: 0.9329 - loss: 0.1925 - val_accuracy: 0.9444 - val_loss: 0.1582 - learning_rate: 5.0000e-05
# Epoch 24/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 101ms/step - accuracy: 0.9323 - loss: 0.2014 - val_accuracy: 0.9397 - val_loss: 0.1713 - learning_rate: 5.0000e-05
# Epoch 25/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 75s 101ms/step - accuracy: 0.9377 - loss: 0.1848 - val_accuracy: 0.9428 - val_loss: 0.1794 - learning_rate: 5.0000e-05
# ✅ Fold 4 Accuracy: 0.9561
#
# 🟦 Fold 5/5
# Found 23758 validated image filenames belonging to 10 classes.
# Found 5939 validated image filenames belonging to 10 classes.
# Epoch 1/25
# /Users/simarkalsi/Projects/leaf K-cross/kcross/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 74s 97ms/step - accuracy: 0.3522 - loss: 1.8980 - val_accuracy: 0.6814 - val_loss: 0.9579 - learning_rate: 1.0000e-04
# Epoch 2/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.6142 - loss: 1.1119 - val_accuracy: 0.7855 - val_loss: 0.6533 - learning_rate: 1.0000e-04
# Epoch 3/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.7031 - loss: 0.8610 - val_accuracy: 0.8212 - val_loss: 0.5521 - learning_rate: 1.0000e-04
# Epoch 4/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.7527 - loss: 0.7294 - val_accuracy: 0.7809 - val_loss: 0.6042 - learning_rate: 1.0000e-04
# Epoch 5/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.7935 - loss: 0.6202 - val_accuracy: 0.8513 - val_loss: 0.4365 - learning_rate: 1.0000e-04
# Epoch 6/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.8162 - loss: 0.5448 - val_accuracy: 0.8567 - val_loss: 0.4156 - learning_rate: 1.0000e-04
# Epoch 7/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 96ms/step - accuracy: 0.8347 - loss: 0.4932 - val_accuracy: 0.8390 - val_loss: 0.4670 - learning_rate: 1.0000e-04
# Epoch 8/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 96ms/step - accuracy: 0.8521 - loss: 0.4418 - val_accuracy: 0.8537 - val_loss: 0.4503 - learning_rate: 1.0000e-04
# Epoch 9/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.8600 - loss: 0.4239 - val_accuracy: 0.9077 - val_loss: 0.2932 - learning_rate: 1.0000e-04
# Epoch 10/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.8730 - loss: 0.3763 - val_accuracy: 0.9113 - val_loss: 0.2710 - learning_rate: 1.0000e-04
# Epoch 11/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.8821 - loss: 0.3461 - val_accuracy: 0.9232 - val_loss: 0.2419 - learning_rate: 1.0000e-04
# Epoch 12/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.8901 - loss: 0.3349 - val_accuracy: 0.9092 - val_loss: 0.2775 - learning_rate: 1.0000e-04
# Epoch 13/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.8943 - loss: 0.3148 - val_accuracy: 0.8604 - val_loss: 0.4190 - learning_rate: 1.0000e-04
# Epoch 14/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9025 - loss: 0.2895 - val_accuracy: 0.8889 - val_loss: 0.3059 - learning_rate: 1.0000e-04
# Epoch 15/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 95ms/step - accuracy: 0.9129 - loss: 0.2606 - val_accuracy: 0.9419 - val_loss: 0.1798 - learning_rate: 5.0000e-05
# Epoch 16/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 71s 96ms/step - accuracy: 0.9147 - loss: 0.2428 - val_accuracy: 0.9460 - val_loss: 0.1629 - learning_rate: 5.0000e-05
# Epoch 17/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 96ms/step - accuracy: 0.9254 - loss: 0.2294 - val_accuracy: 0.9549 - val_loss: 0.1468 - learning_rate: 5.0000e-05
# Epoch 18/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 96ms/step - accuracy: 0.9239 - loss: 0.2296 - val_accuracy: 0.9523 - val_loss: 0.1529 - learning_rate: 5.0000e-05
# Epoch 19/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.9271 - loss: 0.2257 - val_accuracy: 0.9527 - val_loss: 0.1476 - learning_rate: 5.0000e-05
# Epoch 20/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 96ms/step - accuracy: 0.9313 - loss: 0.2100 - val_accuracy: 0.9416 - val_loss: 0.1786 - learning_rate: 5.0000e-05
# Epoch 21/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.9364 - loss: 0.1973 - val_accuracy: 0.9604 - val_loss: 0.1336 - learning_rate: 2.5000e-05
# Epoch 22/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 96ms/step - accuracy: 0.9382 - loss: 0.1874 - val_accuracy: 0.9606 - val_loss: 0.1239 - learning_rate: 2.5000e-05
# Epoch 23/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.9422 - loss: 0.1850 - val_accuracy: 0.9640 - val_loss: 0.1270 - learning_rate: 2.5000e-05
# Epoch 24/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.9369 - loss: 0.1864 - val_accuracy: 0.9616 - val_loss: 0.1213 - learning_rate: 2.5000e-05
# Epoch 25/25
# 743/743 ━━━━━━━━━━━━━━━━━━━━ 72s 97ms/step - accuracy: 0.9380 - loss: 0.1833 - val_accuracy: 0.9646 - val_loss: 0.1204 - learning_rate: 2.5000e-05
# ✅ Fold 5 Accuracy: 0.9646
#
# 📊 5-Fold Validation Accuracy: 0.9585 ± 0.0069

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# For final fold (val_gen still exists)
val_gen.reset()
y_true = val_gen.classes
y_pred = np.argmax(model.predict(val_gen, verbose=1), axis=1)

# Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=val_gen.class_indices.keys()))

# Confusion Matrix
plt.figure(figsize=(12, 8))
sns.heatmap(confusion_matrix(y_true, y_pred), annot=True, fmt='d',
            xticklabels=val_gen.class_indices.keys(),
            yticklabels=val_gen.class_indices.keys(), cmap='Blues')
plt.title("Confusion Matrix (Last Fold)")
plt.ylabel("Actual")
plt.xlabel("Predicted")
plt.show()
# Out:
# 186/186 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step
#
# Classification Report:
#                                              precision    recall  f1-score   support
#
#                       Tomato_Bacterial_spot       0.96      0.98      0.97       629
#                         Tomato_Early_blight       0.94      0.94      0.94       590
#                          Tomato_Late_blight       0.97      0.93      0.95       607
#                            Tomato_Leaf_Mold       0.97      0.99      0.98       595
#                   Tomato_Septoria_leaf_spot       0.98      0.94      0.96       622
# Tomato_Spider_mites_Two_spotted_spider_mite       0.93      0.98      0.95       621
#                         Tomato__Target_Spot       0.95      0.94      0.94       612
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.99      0.98      0.99       479
#                 Tomato__Tomato_mosaic_virus       0.98      1.00      0.99       569
#                              Tomato_healthy       0.99      0.99      0.99       615
#
#                                    accuracy                           0.96      5939
#                                   macro avg       0.97      0.97      0.97      5939
#                                weighted avg       0.96      0.96      0.96      5939

# %%
for i, acc in enumerate(fold_accuracies):
    print(f"Fold {i+1} Accuracy: {acc:.4f}")
print(f"\n📊 Final K-Fold Avg Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")
# Out:
# Fold 1 Accuracy: 0.9460
# Fold 2 Accuracy: 0.9636
# Fold 3 Accuracy: 0.9621
# Fold 4 Accuracy: 0.9561
# Fold 5 Accuracy: 0.9646
#
# 📊 Final K-Fold Avg Accuracy: 0.9585 ± 0.0069

# %%
model.save(f"cnn_kfold_model_fold{fold+1}.keras")

# %%
import matplotlib.pyplot as plt

def plot_cnn_fold_learning_curves(histories, model_name="CNN", fold_type="5-Fold"):
    """
    Plots training vs validation accuracy and loss across multiple folds
    to check for overfitting/underfitting.
    
    Parameters:
    - histories: List of history.history dictionaries (1 per fold)
    - model_name: Name to display in the title (e.g. 'CNN')
    - fold_type: '5-Fold' or '10-Fold'
    """
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    # Accuracy plot
    for i, history in enumerate(histories):
        axs[0].plot(history['accuracy'], label=f'Train Fold {i+1}')
        axs[0].plot(history['val_accuracy'], linestyle='--', label=f'Val Fold {i+1}')

    axs[0].set_title(f'{model_name} {fold_type} Accuracy per Fold')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].legend(loc='lower right')
    axs[0].grid()

    # Loss plot
    for i, history in enumerate(histories):
        axs[1].plot(history['loss'], label=f'Train Fold {i+1}')
        axs[1].plot(history['val_loss'], linestyle='--', label=f'Val Fold {i+1}')

    axs[1].set_title(f'{model_name} {fold_type} Loss per Fold')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].legend(loc='upper right')
    axs[1].grid()

    plt.tight_layout()
    plt.show()

# %%
plot_cnn_fold_learning_curves(fold_histories, model_name="CNN", fold_type="5-Fold")
